# %%
from game import GameField
import numpy as np

# %matplotlib inline
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation

# %%
size = 603
f = GameField(size, b=2.34, per=1, seed=-1)

# %%
f.evolve(500)

# %%
plt.clf()
f.show(40, 10)

# %%
def coop_count(f, size=0):
    if size == 0:
        size = f.size

    return len(
       (1-f.field[f.size - size : f.size + size, f.size - size : f.size + size]).nonzero()[0]
    )

# %%
border_len = coop_count() / 7 * 6 * 4
border_len
# Out:
# 67721.14285714286

# %%
X = range(10, f.size)

# borders count
Y = [np.log(coop_count(f, i)/7*6*4) for i in X]

plt.scatter(np.log(X), Y)
